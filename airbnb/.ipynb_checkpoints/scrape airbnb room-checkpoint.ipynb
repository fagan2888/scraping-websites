# %% [raw]
# roomTable: div class_='_fhph4u'
# room: div class_='_gig1e7'
# guest: div class_='_1nhodd4u'
# price: span class_='_pd52isb'
# rank: span class_='_q27mtmr'
# review: span class_='_1gvnvab'

# %%
from get_room_info import *

# %%
url = 'https://www.airbnb.com.tw/s/Taipei-City/homes?refinement_paths%5B%5D=%2Fhomes&place_id=ChIJi73bYWusQjQRgqQGXK260bw&checkin=2018-09-01&checkout=2018-09-05&query=Taipei%20City&allow_override%5B%5D=&adults=2&s_tag=wJh6U1Ry'
roomList = get_room_list(url)
# Out:
#  18%|█▊        | 3/17 [05:30<25:42, 110.20s/it]
# 2 【寄寓-月租套房】大安館A-大安捷運站僅20m!MRT Da'an Monthly Rental
#  24%|██▎       | 4/17 [07:15<23:35, 108.92s/it]
# 3 【寄寓-月租套房】南京復興館2A MRT Nanjin Fuxing Monthly Rental
#  29%|██▉       | 5/17 [07:23<17:43, 88.61s/it]
# 4 【寄寓-月租套房】大安館F-大安捷運站僅20m!MRT Da'an Monthly Rental
#  88%|████████▊ | 15/17 [08:51<01:10, 35.45s/it]
# 14 西門捷運站 2~7房 一房一廳 電梯大樓
# 100%|██████████| 17/17 [09:18<00:00, 32.84s/it]

# %%
for r in roomList:
    print(r.title)
    print(r.price)
    print(r.rank)
    print(r.district)
    print('\n')
# Out:
# 忠孝新生站3分鐘雙人人文宅/近台北車站/近永康商圈/近忠孝東路/24小時警衛電梯大樓
# 1103
# 5.0
# 中正區
#
#
# 饒河夜市3分鐘, 松山捷運站5分鐘直達西門町 免費wifi 電梯大樓 獨立空間 24小時入住
# 1599
# 5.0
# 松山區
#
#
# *Cozy Studio for 1-4 guests
# 1141
# None
# 萬華區
#
#
# 西門捷運5分鐘雙人套房
# 1425
# None
# 萬華區
#
#
# Love Taipei A3愛台北/捷運忠孝復興站/九份,機場直達巴士/1-2人
# 1362
# 4.5
# 大安區
#
#
# ☆ 台北101不转弯☆3min to MRT-享乐西门町、101、饶河夜市轻松游
# 955
# 5.0
# 信義區
#
#
# 饒河夜市1 min-J MRT SongShan station Taipei 101 五分埔
# 1458
# 5.0
# 松山區
#
#
# Love Taipei K8愛台北/Taipei 101/捷運市政府站/入住1-2人
# 805
# 5.0
# 信義區
#
#
# MRT Dongmen st. 8min on Yongkang Street永康街上近東門站一樓
# 1225
# 5.0
# Da’an District
#
#
# 《新年特惠》西門捷運6分鐘-浴缸四人房
# 1208
# 4.5
# 萬華區
#
#
# Welcome! my friends。私人衛浴 內湖捷運站步行1分鐘松山機場15分，小巨蛋25分
# 1289
# 5.0
# 內湖區
#
#
# ★搶手房源★Zhongxiao Fuxing double MRT
# 1694
# 5.0
# Da’an District
#
#
# MRT Ximan convenience@西門町
# 1094
# 5.0
# 萬華區
#
#
# [BRAND NEW 2BDR] City Hall MRT 10 min+Near 101
# 3054
# 5.0
# 信義區
#
#
# (西門町 Ximending)The Simple Life
# 2025
# 5.0
# 萬華區
#
#
# 全新特價 French Bulldog
# 1675
# 5.0
# ...

# %%
import pickle
file = open(os.getcwd() + '/airbnb-taipei.pkl', 'wb')
pickle.dump(roomList, file)
file.close()
